# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.interpolate import interp1d

# %%
# Define x, y, and xnew to resample at.
#x = np.linspace(0, 10, num=10, endpoint=True)
#y = np.cos(-x**2/9.0)
#pd.read_excel('EXCELFILE.xlsx',sheet_name='Sheet1',header=None,na_values=['NA'],usecols="M:U",skiprows=range(105),nrows=9)
x = pd.read_excel(13-K_Peaks, )
x = np.array(x_pd)
xnew = np.linspace(0, 10, num=400, endpoint=True)
# Out:
#   Cell In[84], line 3
# ...

# %%
# Define interpolators.
f_linear = interp1d(x, y)
f_cubic = interp1d(x, y, kind='cubic')

# %%
# Plot.
plt.plot(x, y, 'o', label='data')
plt.plot(xnew, f_linear(xnew), '-', label='linear')
plt.plot(xnew, f_cubic(xnew), '--', label='cubic')
plt.legend(loc='best')
plt.show()
